# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !git clone -l -s git://github.com/NavinManaswi/IndianSnacks.git
Username: 'XXXX YOUR GitHub User name XXXX'
Password: 'XXXXXX Your Token Here XXXXXXXXXXXX'
# !ls

# %%
import os,shutil
original_dir = "/content/IndianSnacks/IndianSnacksdatasetand code"
test_base_dir = "/content/IndianSnacks/IndianSnacksdatasetand code/test_images"
train_base_dir = "/content/IndianSnacks/IndianSnacksdatasetand code/train_images"

# %%
# Create base directory, train, validation and test directory
base_dir = '/content/base_dir'
os.mkdir(base_dir)

train_dir = os.path.join(base_dir,'train')
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir,'validation')
os.mkdir(validation_dir)

test_dir = os.path.join(base_dir,'test')
os.mkdir(test_dir)

# %%
classes = ['samosa','kachori','aloo_paratha','idli','jalebi','tea','paneer_tikka','dosa','omlet','poha']

test_samosa_dir = os.path.join(test_dir,classes[0])
os.mkdir(test_samosa_dir)

test_kachori_dir = os.path.join(test_dir,classes[1])
os.mkdir(test_kachori_dir)

test_aloo_paratha_dir = os.path.join(test_dir,classes[2])
os.mkdir(test_aloo_paratha_dir)

test_idli_dir = os.path.join(test_dir,classes[3])
os.mkdir(test_idli_dir)

test_jalebi_dir = os.path.join(test_dir,classes[4])
os.mkdir(test_jalebi_dir)

test_tea_dir = os.path.join(test_dir,classes[5])
os.mkdir(test_tea_dir)

test_paneer_tikka_dir = os.path.join(test_dir,classes[6])
os.mkdir(test_paneer_tikka_dir)

test_dosa_dir = os.path.join(test_dir,classes[7])
os.mkdir(test_dosa_dir)

test_omlet_dir = os.path.join(test_dir,classes[8])
os.mkdir(test_omlet_dir)

test_poha_dir = os.path.join(test_dir,classes[9])
os.mkdir(test_poha_dir) 

fnames = [classes[0]+' ({}).JPEG'.format(i) for i in range(8821,9821)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_samosa_dir, fname)
  shutil.copyfile(src, dst) 

  
fnames = [classes[1]+' ({}).JPEG'.format(i) for i in range(5022,6022)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_kachori_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[2]+' ({}).JPEG'.format(i) for i in range(5001,6001)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_aloo_paratha_dir, fname)
  shutil.copyfile(src, dst)
  
  
  
fnames = [classes[3]+' ({}).JPEG'.format(i) for i in range(5001,6001)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_idli_dir, fname)
  shutil.copyfile(src, dst)
  
  
fnames = [classes[4]+' ({}).JPEG'.format(i) for i in range(6001,7001)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_jalebi_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[5]+' ({}).JPEG'.format(i) for i in range(5001,6001)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_tea_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[6]+' ({}).JPEG'.format(i) for i in range(6001,7001)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_paneer_tikka_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[7]+' ({}).JPEG'.format(i) for i in range(5001,6001)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_dosa_dir, fname)
  shutil.copyfile(src, dst)  

fnames = [classes[8]+' ({}).JPEG'.format(i) for i in range(5001,6001)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_omlet_dir, fname)
  shutil.copyfile(src, dst) 
  
fnames = [classes[9]+' ({}).JPEG'.format(i) for i in range(5101,6101)]
for fname in fnames:
  src = os.path.join(test_base_dir, fname)
  #print(src)
  dst = os.path.join(test_poha_dir, fname)
  shutil.copyfile(src, dst)

# %%
print('total testing samosa images:', len(os.listdir(test_samosa_dir)))
print('total testing kachori images:', len(os.listdir(test_kachori_dir)))
print('total testing aloo_paratha images:', len(os.listdir(test_aloo_paratha_dir)))
print('total testing idli images:', len(os.listdir(test_idli_dir)))
print('total testing jalebi images:', len(os.listdir(test_jalebi_dir)))
print('total testing paneer_tikka images:', len(os.listdir(test_paneer_tikka_dir)))
print('total testing dosa images:', len(os.listdir(test_dosa_dir)))
print('total testing omlet images:', len(os.listdir(test_omlet_dir)))
print('total testing poha images:', len(os.listdir(test_poha_dir)))
# Out:
# total testing samosa images: 1000
# total testing kachori images: 1000
# total testing aloo_paratha images: 1000
# total testing idli images: 1000
# total testing jalebi images: 1000
# total testing paneer_tikka images: 1000
# total testing dosa images: 1000
# total testing omlet images: 1000
# total testing poha images: 1000

# %%
# Display one image from each class
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
['samosa','kachori','aloo_paratha','idli','jalebi','tea','paneer_tikka','dosa','omlet','poha']
img_path = ['/content/base_dir/test/samosa/samosa (8821).JPEG','/content/base_dir/test/kachori/kachori (5022).JPEG','/content/base_dir/test/aloo_paratha/aloo_paratha (5001).JPEG',
            '/content/base_dir/test/idli/idli (5001).JPEG',
           '/content/base_dir/test/jalebi/jalebi (6001).JPEG','/content/base_dir/test/tea/tea (5001).JPEG','/content/base_dir/test/paneer_tikka/paneer_tikka (6001).JPEG',
           '/content/base_dir/test/dosa/dosa (5001).JPEG','/content/base_dir/test/omlet/omlet (5001).JPEG','/content/base_dir/test/poha/poha (5101).JPEG']
for i in range(len(img_path)):
  img=mpimg.imread(img_path[i])
  imgplot = plt.imshow(img)
  plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Similarly fill train directory
classes = ['samosa','kachori','aloo_paratha','idli','jalebi','tea','paneer_tikka','dosa','omlet','poha']

train_samosa_dir = os.path.join(train_dir,classes[0])
os.mkdir(train_samosa_dir)

train_kachori_dir = os.path.join(train_dir,classes[1])
os.mkdir(train_kachori_dir)

train_aloo_paratha_dir = os.path.join(train_dir,classes[2])
os.mkdir(train_aloo_paratha_dir)

train_idli_dir = os.path.join(train_dir,classes[3])
os.mkdir(train_idli_dir)

train_jalebi_dir = os.path.join(train_dir,classes[4])
os.mkdir(train_jalebi_dir)

train_tea_dir = os.path.join(train_dir,classes[5])
os.mkdir(train_tea_dir)

train_paneer_tikka_dir = os.path.join(train_dir,classes[6])
os.mkdir(train_paneer_tikka_dir)

train_dosa_dir = os.path.join(train_dir,classes[7])
os.mkdir(train_dosa_dir)

train_omlet_dir = os.path.join(train_dir,classes[8])
os.mkdir(train_omlet_dir)

train_poha_dir = os.path.join(train_dir,classes[9])
os.mkdir(train_poha_dir) 

classes = ['samosa','kachori','aloo_paratha','idli','jalebi','tea','paneer_tikka','dosa','omlet','poha']

fnames = [classes[0]+' ({}).JPEG'.format(i) for i in range(1810,5810)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_samosa_dir, fname)
  shutil.copyfile(src, dst) 

  
fnames = [classes[1]+' ({}).JPEG'.format(i) for i in range(1,3953)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_kachori_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[2]+' ({}).JPEG'.format(i) for i in range(1,4001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_aloo_paratha_dir, fname)
  shutil.copyfile(src, dst)
  
  
  
fnames = [classes[3]+' ({}).JPEG'.format(i) for i in range(1,4001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_idli_dir, fname)
  shutil.copyfile(src, dst)
  
  
fnames = [classes[4]+' ({}).JPEG'.format(i) for i in range(1,4001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_jalebi_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[5]+' ({}).JPEG'.format(i) for i in range(1,4001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_tea_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[6]+' ({}).JPEG'.format(i) for i in range(78,4078)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_paneer_tikka_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[7]+' ({}).JPEG'.format(i) for i in range(1,4001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_dosa_dir, fname)
  shutil.copyfile(src, dst)  

fnames = [classes[8]+' ({}).JPEG'.format(i) for i in range(1,4001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_omlet_dir, fname)
  shutil.copyfile(src, dst) 
  
fnames = [classes[9]+' ({}).JPEG'.format(i) for i in range(1,3975)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(train_poha_dir, fname)
  shutil.copyfile(src, dst)

# %%
print('total training samosa images:', len(os.listdir(train_samosa_dir)))
print('total training kachori images:', len(os.listdir(train_kachori_dir)))
print('total training aloo_paratha images:', len(os.listdir(train_aloo_paratha_dir)))
print('total training idli images:', len(os.listdir(train_idli_dir)))
print('total training jalebi images:', len(os.listdir(train_jalebi_dir)))
print('total training paneer_tikka images:', len(os.listdir(train_paneer_tikka_dir)))
print('total training dosa images:', len(os.listdir(train_dosa_dir)))
print('total training omlet images:', len(os.listdir(train_omlet_dir)))
print('total training poha images:', len(os.listdir(train_poha_dir)))
# Out:
# total training samosa images: 4000
# total training kachori images: 3952
# total training aloo_paratha images: 4000
# total training idli images: 4000
# total training jalebi images: 4000
# total training paneer_tikka images: 4000
# total training dosa images: 4000
# total training omlet images: 4000
# total training poha images: 3974

# %%
# Similarly fill validation directory
classes = ['samosa','kachori','aloo_paratha','idli','jalebi','tea','paneer_tikka','dosa','omlet','poha']

validation_samosa_dir = os.path.join(validation_dir,classes[0])
os.mkdir(validation_samosa_dir)

validation_kachori_dir = os.path.join(validation_dir,classes[1])
os.mkdir(validation_kachori_dir)

validation_aloo_paratha_dir = os.path.join(validation_dir,classes[2])
os.mkdir(validation_aloo_paratha_dir)

validation_idli_dir = os.path.join(validation_dir,classes[3])
os.mkdir(validation_idli_dir)

validation_jalebi_dir = os.path.join(validation_dir,classes[4])
os.mkdir(validation_jalebi_dir)

validation_tea_dir = os.path.join(validation_dir,classes[5])
os.mkdir(validation_tea_dir)

validation_paneer_tikka_dir = os.path.join(validation_dir,classes[6])
os.mkdir(validation_paneer_tikka_dir)

validation_dosa_dir = os.path.join(validation_dir,classes[7])
os.mkdir(validation_dosa_dir)

validation_omlet_dir = os.path.join(validation_dir,classes[8])
os.mkdir(validation_omlet_dir)

validation_poha_dir = os.path.join(validation_dir,classes[9])
os.mkdir(validation_poha_dir) 

fnames = [classes[0]+' ({}).JPEG'.format(i) for i in range(5809,6810)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_samosa_dir, fname)
  shutil.copyfile(src, dst) 

  
fnames = [classes[1]+' ({}).JPEG'.format(i) for i in range(3952,4953)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_kachori_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[2]+' ({}).JPEG'.format(i) for i in range(4001,5001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_aloo_paratha_dir, fname)
  shutil.copyfile(src, dst)
  
  
  
fnames = [classes[3]+' ({}).JPEG'.format(i) for i in range(4001,5001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_idli_dir, fname)
  shutil.copyfile(src, dst)
  
  
fnames = [classes[4]+' ({}).JPEG'.format(i) for i in range(4001,5001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_jalebi_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[5]+' ({}).JPEG'.format(i) for i in range(4001,5001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_tea_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[6]+' ({}).JPEG'.format(i) for i in range(4077,5078)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_paneer_tikka_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = [classes[7]+' ({}).JPEG'.format(i) for i in range(4001,5001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_dosa_dir, fname)
  shutil.copyfile(src, dst)  

fnames = [classes[8]+' ({}).JPEG'.format(i) for i in range(4001,5001)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_omlet_dir, fname)
  shutil.copyfile(src, dst) 
  
fnames = [classes[9]+' ({}).JPEG'.format(i) for i in range(3974,4975)]
for fname in fnames:
  src = os.path.join(train_base_dir, fname)
  #print(src)
  dst = os.path.join(validation_poha_dir, fname)
  shutil.copyfile(src, dst)

# %%
print('total validation samosa images:', len(os.listdir(validation_samosa_dir)))
print('total validation kachori images:', len(os.listdir(validation_kachori_dir)))
print('total validation aloo_paratha images:', len(os.listdir(validation_aloo_paratha_dir)))
print('total validation idli images:', len(os.listdir(validation_idli_dir)))
print('total validation jalebi images:', len(os.listdir(validation_jalebi_dir)))
print('total validation paneer_tikka images:', len(os.listdir(validation_paneer_tikka_dir)))
print('total validation dosa images:', len(os.listdir(validation_dosa_dir)))
print('total validation omlet images:', len(os.listdir(validation_omlet_dir)))
print('total validation poha images:', len(os.listdir(validation_poha_dir)))
# Out:
# total validation samosa images: 1001
# total validation kachori images: 1001
# total validation aloo_paratha images: 1000
# total validation idli images: 1000
# total validation jalebi images: 1000
# total validation paneer_tikka images: 1001
# total validation dosa images: 1000
# total validation omlet images: 1000
# total validation poha images: 1001

# %%
from keras import layers
from keras import models
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
input_shape=(280, 280, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 278, 278, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 139, 139, 32)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 137, 137, 64)      18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 68, 68, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 66, 66, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 33, 33, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 31, 31, 128)       147584
# ...

# %%
from keras import optimizers
model.compile(loss="categorical_crossentropy",metrics=['acc'],optimizer=optimizers.RMSprop(lr=1e-4) )

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
  train_dir,
  target_size=(280, 280),
  batch_size=100,
  class_mode='categorical')


valid_generator = valid_datagen.flow_from_directory(
  validation_dir,
  target_size=(280, 280),
  batch_size=100,
  class_mode='categorical')
# Out:
# Found 39926 images belonging to 10 classes.
# Found 10004 images belonging to 10 classes.

# %%
for data_batch, labels_batch in train_generator:
  print('data batch shape:', data_batch.shape)
  print('labels batch shape:', labels_batch.shape)
  break
# Out:
# data batch shape: (20, 280, 280, 3)
# labels batch shape: (20, 10)

# %%
history = model.fit_generator(train_generator,steps_per_epoch=400,epochs=30,validation_data=valid_generator,validation_steps=100)
# Out:
# Epoch 1/30
# 400/400 [==============================] - 55s 139ms/step - loss: 0.5018 - acc: 0.8465 - val_loss: 0.3643 - val_acc: 0.8775
# Epoch 2/30
# 400/400 [==============================] - 55s 138ms/step - loss: 0.1465 - acc: 0.9545 - val_loss: 0.0476 - val_acc: 0.9885
# Epoch 3/30
# 400/400 [==============================] - 55s 138ms/step - loss: 0.0810 - acc: 0.9765 - val_loss: 0.0209 - val_acc: 0.9915
# Epoch 4/30
# 400/400 [==============================] - 55s 138ms/step - loss: 0.0370 - acc: 0.9879 - val_loss: 0.0118 - val_acc: 0.9965
# Epoch 5/30
# 400/400 [==============================] - 56s 139ms/step - loss: 0.0318 - acc: 0.9902 - val_loss: 0.0812 - val_acc: 0.9758
# Epoch 6/30
# 400/400 [==============================] - 55s 138ms/step - loss: 0.0203 - acc: 0.9947 - val_loss: 0.0117 - val_acc: 0.9970
# Epoch 7/30
# 400/400 [==============================] - 55s 138ms/step - loss: 0.0181 - acc: 0.9939 - val_loss: 0.0118 - val_acc: 0.9960
# Epoch 8/30
# ...

# %%
import matplotlib.pyplot as plt
acc= history.history['acc']
val_acc= history.history['val_acc']
loss= history.history['loss']
val_loss= history.history['val_loss']

epochs = range(1,len(acc)+1)

plt.plot(epochs,acc,'bo',label="Training accuracy")
plt.plot(epochs,val_acc,'b',label="Validation accuracy")
plt.title('Training and validation accuracy')
plt.figure()

plt.plot(epochs,loss,'bo',label="Training Loss")
plt.plot(epochs,val_loss,'b',label="Validation LOss")
plt.title('Training and validation loss')
plt.show()

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
  test_dir,
  target_size=(280, 280),
  batch_size=100,
  class_mode='categorical')


predict = model.evaluate_generator (test_generator,steps = 100)
# Out:
# Found 10000 images belonging to 10 classes.

# %%
predict
# Out:
# 0.9993000006675721

# %%
from keras.preprocessing import image
class_label = ['aloo_paratha','dosa','idli','jalebi','kachori','omlet','paneer_tikka','poha','samosa','tea']
img = image.load_img('/content/tea.jpeg', target_size=(280, 280))
plt.imshow(img)
x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = x /255.
index = (model.predict_classes(x)[0])

print("Label is "+str(class_label[index]))
# Out:
# Label is tea

# %%
from keras.preprocessing import image
class_label = ['aloo_paratha','dosa','idli','jalebi','kachori','omlet','paneer_tikka','poha','samosa','tea']
img = image.load_img('/content/panner_tika.jpeg', target_size=(280, 280))
plt.imshow(img)
x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = x /255.
index = (model.predict_classes(x)[0])

print("Label is "+str(class_label[index]))
# Out:
# Label is paneer_tikka

# %%
from keras.preprocessing import image
class_label = ['aloo_paratha','dosa','idli','jalebi','kachori','omlet','paneer_tikka','poha','samosa','tea']
img = image.load_img('/content/poha.jpeg', target_size=(280, 280))
plt.imshow(img)
x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = x /255.
index = (model.predict_classes(x)[0])

print("Label is "+str(class_label[index]))
# Out:
# Label is poha
